# %% [markdown]
# ### **產業據點與區位**

# %% [markdown]
# &emsp;&emsp;截至2025年12月花蓮都會區（指花蓮市與吉安鄉，亦包含新城鄉嘉禮村）尚在營業的製材廠與建材行約有19間，在空間選址上多集中在里漏部落附近的工業區與**田浦車站**一帶。標記年份為營業登記年，並非是確切的開業時間（年份資料來源：台灣公司網）。

# %%
import folium
hualien_center = [23.9769, 121.6044]
wood_shops = [
    {"name": "大源木業股份有限公司", "lat": 23.9631485, "lon": 121.5733806, "year": 1969},
    {"name": "朝盛木材行", "lat": 23.9765539, "lon": 121.586245, "year": 2014},
    {"name": "大永發建材行", "lat": 23.9712618, "lon": 121.6014286, "year": 1979},
    {"name": "東新木業行", "lat": 23.9721847, "lon": 121.5780551, "year": 1980},
    {"name": "嘉益木材行", "lat": 23.9511861, "lon": 121.590686, "year": 1973},
    {"name": "松梧木材行", "lat": 23.95916, "lon": 121.593787, "year": 1994},
    {"name": "勝裕建材行", "lat": 23.9977314, "lon": 121.6017339},
    {"name": "華信昌實業", "lat": 23.9547848, "lon": 121.5631098, "year": 2004},
    {"name": "崇成建材行", "lat": 23.9736972, "lon": 121.5737778, "year": 2005},
    {"name": "老傳建材行", "lat": 23.9728321, "lon": 121.5996267, "year": 2002},
    {"name": "豪臆建材行", "lat": 23.9829324, "lon": 121.5812487, "year": 1992},
    {"name": "祥捷木業", "lat": 23.9751049, "lon": 121.5736817, "year": 1992},
    {"name": "立健木業", "lat": 23.9805185, "lon": 121.5898376, "year": 1993},
    {"name": "吉興板模", "lat": 23.9779513, "lon": 121.5888936, "year": 1977},
    {"name": "宏銘企業股份有限公司", "lat": 23.9764884, "lon": 121.5848797, "year": 1967},
    {"name": "力元建材行", "lat": 23.952665, "lon": 121.590732, "year": 1983},
    {"name": "一成木材行", "lat": 23.9729168, "lon": 121.6015107, "year": 1978},
    {"name": "燕茂企業股份有限公司", "lat": 23.9571253, "lon": 121.593387, "year": 1973},
]
def year_category(year):
    if year is None:
        return "無年份"
    elif year < 1990:
        return "1990年以前"
    else:
        return "1990年（含）以後"
category_colors = {
    "1990年以前": "green",
    "1990年（含）以後": "red",
    "無年份": "gray"
}
m = folium.Map(
    location=hualien_center,
    zoom_start=13,
    tiles="CartoDB positron"
)

for shop in wood_shops:
    year = shop.get("year")
    category = year_category(year)
    color = category_colors[category]

    popup_text = shop["name"]
    popup_text += f"<br>營業登記年：{year}" if year else "<br>營業登記年：未知"

    folium.Marker(
        location=[shop["lat"], shop["lon"]],
        popup=popup_text,
        icon=folium.Icon(color=color, icon="tree", prefix="fa")
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6af92fe8768be508feac6598a6fbe18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6af92fe8768be508feac6598a6fbe18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6af92fe8768be508feac6598a6fbe18 = L.map(
#                 &quot;map_a6af92fe8768be508feac6598a6fbe18&quot;,
#                 {
#                     center: [23.9769, 121.6044],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7d6b40e69fbd9c28fa17b0ebe54d392 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7d6b40e69fbd9c28fa17b0ebe54d392.addTo(map_a6af92fe8768be508feac6598a6fbe18);
#
#
#             var marker_7748d18099464cd63dfa278d280428c7 = L.marker(
#                 [23.9631485, 121.5733806],
#                 {
# }
#             ).addTo(map_a6af92fe8768be508feac6598a6fbe18);
#
#
#             var icon_45472b642d0a9445c01f9c93180cbeac = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_249c66fe56a55b149c5c55951888e2f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99886a0c9476012319a66fa20abc7667 = $(`&lt;div id=&quot;html_99886a0c9476012319a66fa20abc7667&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大源木業股份有限公司&lt;br&gt;營業登記年：1969&lt;/div&gt;`)[0];
#                 popup_249c66fe56a55b149c5c55951888e2f1.setContent(html_99886a0c9476012319a66fa20abc7667);
#
#
#
#         marker_7748d18099464cd63dfa278d280428c7.bindPopup(popup_249c66fe56a55b149c5c55951888e2f1)
#         ;
#
#
#
#
#                 marker_7748d18099464cd63dfa278d280428c7.setIcon(icon_45472b642d0a9445c01f9c93180cbeac);
#
#
#             var marker_8ca4e2ff4eba1f07b98a8c3c9b5bdd1e = L.marker(
#                 [23.9765539, 121.586245],
#                 {
# }
#             ).addTo(map_a6af92fe8768be508feac6598a6fbe18);
#
#
#             var icon_e09f54b07c186853be978835f6bdf287 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6277313b3f5cfcf86ce7e7e76ebf8a5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d7eba1ad5f12a1c2eb1398b4eb5ae0a = $(`&lt;div id=&quot;html_9d7eba1ad5f12a1c2eb1398b4eb5ae0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;朝盛木材行&lt;br&gt;營業登記年：2014&lt;/div&gt;`)[0];
#                 popup_6277313b3f5cfcf86ce7e7e76ebf8a5e.setContent(html_9d7eba1ad5f12a1c2eb1398b4eb5ae0a);
#
#
#
#         marker_8ca4e2ff4eba1f07b98a8c3c9b5bdd1e.bindPopup(popup_6277313b3f5cfcf86ce7e7e76ebf8a5e)
#         ;
#
#
#
#
#                 marker_8ca4e2ff4eba1f07b98a8c3c9b5bdd1e.setIcon(icon_e09f54b07c186853be978835f6bdf287);
#
#
#             var marker_aaa98e359205022c7cc5ecebb542628a = L.marker(
#                 [23.9712618, 121.6014286],
#                 {
# }
#             ).addTo(map_a6af92fe8768be508feac6598a6fbe18);
#
#
#             var icon_75f3f53b66d01c08a0125444746ba410 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;tree&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8c3df4e88cc6a08a35ece6cae36a958a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcaf9100965d2dd766c9fc275860094f = $(`&lt;div id=&quot;html_fcaf9100965d2dd766c9fc275860094f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大永發建材行&lt;br&gt;營業登記年：1979&lt;/div&gt;`)[0];
#                 popup_8c3df4e88cc6a08a35ece6cae36a958a.setContent(html_fcaf9100965d2dd766c9fc275860094f);
#
#
#
#         marker_aaa98e359205022c7cc5ecebb542628a.bindPopup(popup_8c3df4e88cc6a08a35ece6cae36a958a)
#         ;
#
#
#
#
#                 marker_aaa98e359205022c7cc

# %% [markdown]
# #### 田浦的區位因素

# %%
import folium
from folium.plugins import HeatMap

hualien_center = [23.9769, 121.6044]
wood_shops = [
    {"name": "大源木業", "lat": 23.9631485, "lon": 121.5733806},
    {"name": "朝盛木材行", "lat": 23.9765539, "lon": 121.586245},
    {"name": "大永發建材行", "lat": 23.9712618, "lon": 121.6014286},
    {"name": "東新木業行", "lat": 23.9721847, "lon": 121.5780551},
    {"name": "嘉益木材行", "lat": 23.9511861, "lon": 121.590686},
    {"name": "松梧木材行", "lat": 23.95916, "lon": 121.593787},
    {"name": "勝裕建材行", "lat": 23.9977314, "lon": 121.6017339},
    {"name": "華信昌實業", "lat": 23.9547848, "lon": 121.5631098},
    {"name": "崇成建材行", "lat": 23.9736972, "lon": 121.5737778},
    {"name": "老傳建材行", "lat": 23.9728321, "lon": 121.5996267},
    {"name": "豪臆建材行", "lat": 23.9829324, "lon": 121.5812487},
    {"name": "祥捷木業", "lat": 23.9751049, "lon": 121.5736817},
    {"name": "立健木業", "lat": 23.9805185, "lon": 121.5898376},
    {"name": "吉興板模", "lat": 23.9779513, "lon": 121.5888936},
    {"name": "宏銘企業股份有限公司", "lat": 23.9764884, "lon": 121.5848797},
    {"name": "力元建材行", "lat": 23.952665, "lon": 121.590732},
    {"name": "一成木材行", "lat": 23.9729168, "lon": 121.6015107},
    {"name": "燕茂企業股份有限公司", "lat": 23.9571253, "lon": 121.593387},
]

m = folium.Map(location=hualien_center, zoom_start=10.5, tiles="CartoDB positron")
heat_data = [[shop["lat"], shop["lon"]] for shop in wood_shops]
HeatMap(heat_data, radius=13, blur=15).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe81baa55d7261e32c03f02169bfcc9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe81baa55d7261e32c03f02169bfcc9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe81baa55d7261e32c03f02169bfcc9f = L.map(
#                 &quot;map_fe81baa55d7261e32c03f02169bfcc9f&quot;,
#                 {
#                     center: [23.9769, 121.6044],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fba85870d1669607f16f14cbf0cea9a7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fba85870d1669607f16f14cbf0cea9a7.addTo(map_fe81baa55d7261e32c03f02169bfcc9f);
#
#
#             var heat_map_b814de2b26cdfa8c84db5b4c6585fa38 = L.heatLayer(
#                 [[23.9631485, 121.5733806], [23.9765539, 121.586245], [23.9712618, 121.6014286], [23.9721847, 121.5780551], [23.9511861, 121.590686], [23.95916, 121.593787], [23.9977314, 121.6017339], [23.9547848, 121.5631098], [23.9736972, 121.5737778], [23.9728321, 121.5996267], [23.9829324, 121.5812487], [23.9751049, 121.5736817], [23.9805185, 121.5898376], [23.9779513, 121.5888936], [23.9764884, 121.5848797], [23.952665, 121.590732], [23.9729168, 121.6015107], [23.9571253, 121.593387]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 13,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_b814de2b26cdfa8c84db5b4c6585fa38.addTo(map_fe81baa55d7261e32c03f02169bfcc9f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
